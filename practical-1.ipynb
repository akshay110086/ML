# %%
a=5
b=10

# %% [markdown]
# # Addition

# %%
a+b
# Out:
# 15

# %% [markdown]
# # Multiplication

# %%
a*b
# Out:
# 50

# %% [markdown]
# # Division

# %%
a/b
# Out:
# 0.5

# %% [markdown]
# # Exponentiation

# %%
a**b
# Out:
# 9765625
